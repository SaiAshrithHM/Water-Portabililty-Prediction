# %% [markdown]
# # **Water Potability Prediction**

# %% [markdown]
# ### **Introduction**
#
# Access to clean and potable water is essential for human health and well-being. However, water contamination caused by chemical and physical pollutants poses a significant public health risk. Traditional water quality assessment methods can be time-consuming and resource-intensive, necessitating the development of automated predictive systems. This project aims to leverage machine learning techniques to predict **water potability** based on key physicochemical parameters.
#
# The dataset used in this study contains **nine crucial water quality indicators**:
#
# - **pH** – Measures the acidity or alkalinity of water, affecting its suitability for consumption.
#
# - **Hardness** – Indicates the concentration of dissolved minerals like calcium and magnesium.
#
# - **Solids** – Represents total dissolved solids (TDS), which can influence water taste and safety.
#
# - **Chloramines** – A disinfectant used to treat water but can be harmful at high levels.
#
# - **Sulfate** – A naturally occurring substance that, in excess, can lead to gastrointestinal issues.
#
# - **Conductivity** – Measures the water's ability to conduct electricity, linked to ion concentration.
#
# - **Organic Carbon** – Indicates the presence of organic contaminants, which may impact water quality.
#
# - **Trihalomethanes (THMs)** – Byproducts of chlorination, known to pose health risks at high levels.
#
# - **Turbidity** – Measures water clarity, with high values indicating potential contamination.
#
# The objective of this project is to **develop an accurate classification model that predicts water potability** based on these attributes. By analyzing large-scale water quality data, the model will help **identify non-potable water sources, support regulatory compliance, and optimize water treatment processes**.
#
# The successful implementation of this predictive system could have a profound impact on **public health, water resource management, and environmental sustainability**. It can assist water treatment facilities, regulatory bodies, and local communities in making **data-driven decisions to ensure the availability of safe drinking water**.
#
#
#
# ---

# %% [markdown]
# ### **Summary of the Water Potability Dataset**
#
# **Dataset Overview:**
#
# The dataset contains 3,276 rows and 10 columns.
# The target variable is "Potability", which indicates whether the water is safe to drink (1) or not (0).
#
# **Column Details:**
#
# The dataset includes various water quality parameters such as pH, Hardness, Solids, Chloramines, Sulfate, Conductivity, Organic Carbon, Trihalomethanes, and Turbidity.
#
# **Missing Values:**
#
# pH: 491 missing values
# Sulfate: 781 missing values
# Trihalomethanes: 162 missing values
# Other columns have no missing values.
#
# **Key Statistical Insights:**
#
# - pH: Ranges from 0 to 14, but has missing values.
#
# - Hardness: Averages 196.37 mg/L, ranging from 47.43 to 323.12 mg/L.
#
# - Solids: Mean value of 22,014.09 mg/L, max reaching 61,227.19 mg/L.
#
# - Chloramines: Mean value of 7.12 mg/L, max at 13.13 mg/L.
#
# - Sulfate: Mean of 333.78 mg/L, with values ranging from 129.0 to 481.03 mg/L.
#
# - Conductivity: Averages 426.2 μS/cm, with max at 753.34 μS/cm.
#
# - Organic Carbon: Mean 14.28 mg/L, peaking at 28.3 mg/L.
#
# - Trihalomethanes: Mean 66.39 μg/L, with missing values present.
#
# - Turbidity: Mean 3.97 NTU, max at 6.739 NTU.
#
# - Potability Distribution: The dataset is imbalanced with only 39% (1,278 samples) of the water samples marked as potable, and 61% (1,998 samples) as non-potable.
#
# ---

# %% [markdown]
# ### The Below Columns Show For Better Understanding Of The Data
# ---

# %% [markdown]
# - **PH** : Indicator of acidic or alkaline condition of water, ranging from 1 to 14.
#
#   Acceptable Limit: 6.5 to 8.5
#
# - **Hardness** : Capacity of water to precipitate soap in mg/L, ranging from  47 to 324.
#
#   Acceptable Limit: Upto 500 or 600 mg/L
#
# - **Solids** : Total dissolved solids (TDS) in ppm. The water with high TDS value indicates that water is highly mineralized, ranging from 320 to 61228.
#
#   Acceptable Limit: 500 - 1000 ppm
#
# - **Chloramines** : Amount of Chloramines in ppm, ranging from 0 to 14.
#
#   Acceptable Limit: Upto 4 ppm
#
# - **Sulfate** : Amount of Sulfates dissolved in water in mg/L, ranging from 129 to 482.
#
#   Acceptable Limit: Upto 400 mg/L
#
# - **Conductivity** : Electrical conductivity of water in μS/cm, ranging from 181 to 754.
#
#   Acceptable Limit: Upto 400 μS/cm
#
# - **Organic_carbon** : Amount of carbon in organic compounds in ppm, ranging from 2 to 29.
#
#   Acceptable Limit: Less than 2 mg/L
#
# - **Trihalomethanes** : Amount of Trihalomethanes in μg/L, ranging from 0 to 124.
#
#   Acceptable Limit: Upto 80 ppm
#
# - **Turbidity** : Measure of light emiting property of water in NTU, ranging from 1 to 7.
#
#   Acceptable Limit: 5-10 NTU
#
# - **Potability** : Indicates if water is safe for human consumption, ranging from 0 to 1.
#
#   Here Potable -1 and Not potable -0.
#
#   ---

# %% [markdown]
# <table>
#     <tr>
#         <th>Features</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <td>pH</td>
#         <td>pH of water</td>
#     </tr>
#     <tr>
#         <td>Hardness</td>
#         <td>Capacity of water to precipitate soap in mg/L</td>
#     </tr>
#     <tr>
#         <td>Solids</td>
#         <td>Total dissolved solids in ppm</td>
#     </tr>
#     <tr>
#         <td>Chloramines</td>
#         <td>Amount of Chloramines in ppm</td>
#     </tr>
#     <tr>
#         <td>Sulfate</td>
#         <td>Amount of Sulfates dissolved in mg/L</td>
#     </tr>
#     <tr>
#         <td>Conductivity</td>
#         <td>Electrical conductivity of water in μS/cm</td>
#     </tr>
#     <tr>
#         <td>Organic_carbon</td>
#         <td>Amount of organic carbon in ppm</td>
#     </tr>
#     <tr>
#         <td>Trihalomethanes</td>
#         <td>Amount of Trihalomethanes in μg/L</td>
#     </tr>
#     <tr>
#         <td>Turbidity</td>
#         <td>Measure of light emiting property of water in NTU</td>
#     </tr>
#      <tr>
#         <td>Potability</td>
#         <td>Indicates if water is safe for human consumption. Potable- 1 and Not potable- 0</td>
#     </tr>
# </table>
#
# ---

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import floor,ceil
import tabulate as tb

# %%
# %matplotlib inline

# %%
water_df = pd.read_csv("water_potability.csv")

# %%
water_df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# Displaying the first five rows, we can see that we have missing values, which we have to handle before training the model.

# %%
water_df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
water_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# ### Checking for the range of the features in Data

# %%
l=[]
names=[]
for col in water_df.columns:
    names.append(col)
    l.append(f'{floor(water_df[col].min())} to {ceil(water_df[col].max())}')

tab = pd.DataFrame(list(zip(names,l)),columns =['Name', 'Range'])
print(tb.tabulate(tab, headers='keys', tablefmt='pretty'))
# Out:
# +---+-----------------+--------------+
# |   |      Name       |    Range     |
# +---+-----------------+--------------+
# | 0 |       ph        |   0 to 14    |
# | 1 |    Hardness     |  47 to 324   |
# | 2 |     Solids      | 320 to 61228 |
# | 3 |   Chloramines   |   0 to 14    |
# | 4 |     Sulfate     |  129 to 482  |
# | 5 |  Conductivity   |  181 to 754  |
# | 6 | Organic_carbon  |   2 to 29    |
# | 7 | Trihalomethanes |   0 to 124   |
# | 8 |    Turbidity    |    1 to 7    |
# | 9 |   Potability    |    0 to 1    |
# +---+-----------------+--------------+

# %% [markdown]
# ### The above tabel shows the minimum and maximum range of the each feature in the dataset

# %% [markdown]
# ### Checking for Nulls in the Data

# %%
print(f"Dataset shape: {water_df.shape}")
print("\nFeatures with missing values: ")
print(water_df.isnull().sum())
# Out:
# Dataset shape: (3276, 10)
#
# Features with missing values:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# ### * ph feature has almost 15% of data missing.
# ### * Sulfate feature has almost 24% of data missing.
# ### * Trihalomethanes feature has almost 5% missing data.
#
# ---

# %% [markdown]
# #### If we drop all the missing values from the data frame, we lose more than 30% of the dataset. Instead, we will fill this data using KNNImpputer.

# %% [markdown]
# ### Filling Missing values using KNNImputer

# %%
from sklearn.impute import KNNImputer

# %% [markdown]
# #### * Here we are using knn imputer to treat missing values.
# #### * Why knn : it is much more accurate than the mean,median,mode and other imputation methods.
# #### * Why not mean/median/mode : it can introduce bias in the data.

# %%
imputer = KNNImputer(n_neighbors=5, weights="uniform",add_indicator=False)
data=imputer.fit_transform(water_df)
water_df1=pd.DataFrame(data,columns=water_df.columns)
water_df1.to_csv("1clean_dataset.csv", index=False)

# %% [markdown]
# ### Saving cleaned dataset as a new dataset

# %%
water_df1 = pd.read_csv("1clean_dataset.csv")

# %% [markdown]
# ### Checking distributions

# %%
water_df1.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.078167   196.369496  22014.092526     7.122277   333.605767
# std       1.497228    32.879761   8768.570828     1.583085    37.453055
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.187017   176.850538  15666.690297     6.127421   312.389295
# 50%       7.052221   196.967627  20927.833607     7.130299   333.255192
# 75%       7.948570   216.667456  27332.762127     8.114887   355.013586
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.403218     3.966786     0.390110
# std       80.824064        3.308162        15.837754     0.780382     0.487849
# ...

# %%
water_df1[water_df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ph, Hardness, Solids, Chloramines, Sulfate, Conductivity, Organic_carbon, Trihalomethanes, Turbidity, Potability]
# Index: []

# %% [markdown]
# ### There are to duplicates in the dataset
# ---

# %%
water_df1 = pd.read_csv("1clean_dataset.csv")
display(water_df1.head())
print(water_df1.info())
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.156857  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  336.094350    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  330.449166    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135         0.0
# 1       15.180013        56.329076   4.500656         0.0
# 2       16.868637        66.420093   3.055934         0.0
# 3       18.436524       100.341674   4.628771         0.0
# 4       11.558279        31.997993   4.075075         0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ...

# %%
print(water_df1["Potability"].value_counts())
sns.countplot(x="Potability", data=water_df1)
plt.show()
# Out:
# Potability
# 0.0    1998
# 1.0    1278
# Name: count, dtype: int64

# %%
print(f"Potable water data percentaje: {1278/water_df1.shape[0]*100:.2f}%")
print(f"Non-potable water data percentaje: {1998/water_df1.shape[0]*100:.2f}%")
# Out:
# Potable water data percentaje: 39.01%
# Non-potable water data percentaje: 60.99%

# %% [markdown]
# ### **Observation:**
# - We have mild imbalanced data; as we can see, only 39.01% of our data is for potable water, which may cause problems when we train our model.
# - Knowing the ratio for our classes, let's make some multi-variate analysis.
# ---

# %% [markdown]
# ### Checking for data distribution

# %%
water_df1.drop(["Potability"], axis=1).hist(figsize=(12,8),bins=20)
plt.show()

# %% [markdown]
# ## The water quality parameters exhibit normal distributions, ensuring balanced data for modeling.
# #### Pros: No extreme skewness, well-distributed values.
# #### Cons: Potential outliers, some high variance in sulfate and solids.
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

sns.pairplot(data=water_df1, hue="Potability", diag_kind="kde", palette="coolwarm", markers=["o", "s"])

plt.show()

# %% [markdown]
# ### **Observation:**
# The data is really spread between classes, which probably means that we won't use a linear classifier for our model.
#
# ---

# %% [markdown]
# ### Checking for corelation in the dataset

# %%
plt.figure(figsize=(10,6))
sns.heatmap(water_df1.corr(),cmap=plt.cm.Reds,annot=True)
plt.title('Heatmap displaying the relationship betweennthe features of the data',fontsize=13)
plt.show()

# %% [markdown]
# ### **Observation:**
# As expected (Based on the Heatmap), the correlation between our variables is low. We have negative and positive correlations, but the majority didn't reach 0.1 of correlation.
#
# ---

# %% [markdown]
# ### Checking for outliers in the dataset

# %%
# %%capture --no-display

fig, ax = plt.subplots(9, 2, figsize = (15, 13))
for idx, col in enumerate(water_df1.drop(["Potability"], axis=1).columns.to_list()):
    sns.boxplot(x=col, data=water_df1, ax=ax[idx, 0])
    sns.distplot(water_df1[col], ax=ax[idx, 1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Observation:**
# - Most of the features are similar to a normal distribution, except for Solids which is slightly tilted to the left.
# - We have some outliers on each feature, and the data distribution has more than one feature tilted to the left.

# %% [markdown]
# ### **Conclusions**
# - The features don't have a linear correlation between them, so we can't use a linear classifier to separate our classes.
# - All the features have multiple outliers; we need an algorithm non-sensible to these values.
# - The dataset is mildly imbalanced; before training the model, we must preprocess the data and balance it.

# %% [markdown]
# ---
# ## **Outliers treatment**

# %%
import numpy as np
def treat_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[column] = np.clip(df[column], lower_bound, upper_bound)
    return df

for col in water_df1.drop(["Potability"], axis=1).columns.to_list():
    water_df1 = treat_outliers_iqr(water_df1, col)

# %%
import joblib
from sklearn.preprocessing import MinMaxScaler

numerical_cols = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity']

scaler = MinMaxScaler()

water_df1[numerical_cols] = scaler.fit_transform(water_df1[numerical_cols])

# Save scaler model
scaler_path = "models/scaler.save"
joblib.dump(scaler, scaler_path)
print(f"Scaler model saved successfully at {scaler_path}")

print(water_df1.head())
# Out:
# Scaler model saved successfully at models/scaler.save
#          ph  Hardness    Solids  Chloramines   Sulfate  Conductivity  \
# 0  0.512640  0.551055  0.459896     0.522523  0.704197      0.802748
# 1  0.024324  0.077214  0.411340     0.438878  0.514035      0.864305
# 2  0.646367  0.672523  0.440085     0.771040  0.480925      0.488891
# 3  0.677254  0.610596  0.487464     0.618012  0.635983      0.369684
# 4  0.787308  0.401691  0.396713     0.427728  0.361782      0.445388
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0        0.281162         0.749151   0.262665         0.0
# 1        0.548326         0.374019   0.625079         0.0
# 2        0.642308         0.497477   0.284538         0.0
# 3        0.729571         0.912490   0.655278         0.0
# 4        0.346753         0.076341   0.524764         0.0

# %% [markdown]
# ### I have saved the Scaler Model for the deployment.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ---
# ## Handling Class Imbalance by Balance data using SMOTE.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
import pandas as pd

# Assuming 'water_df1' is your original dataset with features and target variable
X = water_df1.drop(columns=['Potability'])  # Features
y = water_df1['Potability']  # Target

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Convert back to DataFrame for clarity
X_resampled = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled = pd.Series(y_resampled, name='Potability')

# Combine back into a single DataFrame (if needed)
water_df1_resampled = pd.concat([X_resampled, y_resampled], axis=1)

# Check the new class distribution
print("Class distribution after SMOTE:")
print(y_resampled.value_counts())

# Verify dataset shape
print("New dataset shape:", water_df1_resampled.shape)  # Should match (3996, 10) if originally (3276, 10)
# Out:
# Class distribution after SMOTE:
# Potability
# 0.0    1998
# 1.0    1998
# Name: count, dtype: int64
# New dataset shape: (3996, 10)

# %% [markdown]
# ### **Observation:**
# After applying SMOTE the shape of the dataset have been increased , Originally it was Dataset shape: (3276, 10)

# %% [markdown]
# ---
# ## Spliting the data for training and testing

# %%
from sklearn.model_selection import train_test_split

# Compute the correct test size
test_size = 802 / 3208  # 25% of 3208

X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=test_size, random_state=42, stratify=y_resampled
)

# Print the final shapes
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (2997, 9)
# y_train shape: (2997,)
# X_test shape: (999, 9)
# y_test shape: (999,)

# %% [markdown]
# ---
# ## Model Selection

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# Ensure X_train is a DataFrame
if not isinstance(X_train, pd.DataFrame):
    X_train = pd.DataFrame(X_train)

# Ensure data is numeric
X_train = X_train.astype(float)

# Convert y_train to a NumPy array and ensure it's 1D
y_train = np.ravel(y_train)

# Initialize classifiers
classifiers = {
    'SVC': SVC(),
    'Random Forest': RandomForestClassifier(),
    'KNN': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

# Dictionary to store results
results = {}

# Perform 5-fold cross-validation and store results
for name, clf in classifiers.items():
    scores = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
    results[name] = scores

# Print results
print("\n🔹 **Cross-Validation Results:**")
for name, scores in results.items():
    print(f"{name}:")
    print(f"  Accuracy scores: {scores}")
    print(f"  Mean Accuracy: {scores.mean():.3f}")
    print(f"  Standard Deviation: {scores.std():.3f}")
    print("-" * 40)
# Out:
# c:\Users\Pavan Achari\.conda\envs\water_potablility\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:45:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Pavan Achari\.conda\envs\water_potablility\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:45:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\Pavan Achari\.conda\envs\water_potablility\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:45:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# ...

# %% [markdown]
# ### **Observation:**
# As we can see Random Forest is performing best with the accuracy scores of 71%
#
# ---

# %% [markdown]
# ## Hyperparameter Tuning: Optimizing model with RandomizedSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Define the parameter grid
param_dist = {
    'n_estimators': np.arange(50, 300, 50),  # Number of trees in the forest
    'max_depth': [None, 10, 20, 30, 40],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4],  # Minimum samples required in a leaf node
    'bootstrap': [True, False]  # Whether to use bootstrap samples
}

# Initialize the Random Forest classifier
rf = RandomForestClassifier(random_state=42)

# Use RandomizedSearchCV to tune hyperparameters
random_search = RandomizedSearchCV(
    estimator=rf, param_distributions=param_dist,
    n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42, verbose=2
)

# Fit the model
random_search.fit(X_train, y_train)

# Print best parameters and best score
print("Best Parameters:", random_search.best_params_)
print("Best Accuracy:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'n_estimators': 150, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 40, 'bootstrap': False}
# Best Accuracy: 0.725056204785754

# %% [markdown]
# ## Also Hyperparameter Tuning: Optimizing model with GridSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize the Random Forest classifier
rf = RandomForestClassifier(random_state=42)

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

# Fit the model to training data
grid_search.fit(X_train, y_train)

# Print best parameters and best accuracy
print("Best Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Best Parameters: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best Accuracy: 0.7307278797996661

# %% [markdown]
# ## **Observation:**
# As we can see the GridSearchCV has Best Accuracy of 73%.

# %%
from sklearn.ensemble import RandomForestClassifier

# Best parameters from GridSearchCV
best_params = {
    'bootstrap': False,
    'max_depth': 20,
    'min_samples_leaf': 1,
    'min_samples_split': 2,
    'n_estimators': 200
}

# Train the final model
final_rf_model = RandomForestClassifier(**best_params, random_state=42)
final_rf_model.fit(X_train, y_train)

# Evaluate on test data
test_accuracy = final_rf_model.score(X_test, y_test)
print(f"Final Model Test Accuracy: {test_accuracy:.3f}")
# Out:
# Final Model Test Accuracy: 0.713

# %% [markdown]
# ---
# ## Model Evaluation

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Make predictions on the test set
y_pred = final_rf_model.predict(X_test)
y_proba = final_rf_model.predict_proba(X_test)[:, 1]  # Probability scores for ROC/AUC

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Precision, Recall, F1-Score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# ROC Curve & AUC Score
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Print Evaluation Metrics
print("🔹 **Model Performance Metrics**")
print(f"✅ Accuracy: {accuracy:.3f}")
print(f"✅ Precision: {precision:.3f}")
print(f"✅ Recall: {recall:.3f}")
print(f"✅ F1 Score: {f1:.3f}")
print(f"✅ AUC Score: {roc_auc:.3f}\n")
print("🔹 **Classification Report**")
print(classification_report(y_test, y_pred))

# Plot Confusion Matrix
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Not Potable", "Potable"], yticklabels=["Not Potable", "Potable"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# Plot ROC Curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC = {roc_auc:.3f}')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random guessing line
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()
# Out:
# 🔹 **Model Performance Metrics**
# ✅ Accuracy: 0.713
# ✅ Precision: 0.719
# ✅ Recall: 0.697
# ✅ F1 Score: 0.708
# ✅ AUC Score: 0.794
#
# 🔹 **Classification Report**
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.73      0.72       500
#          1.0       0.72      0.70      0.71       499
#
#     accuracy                           0.71       999
#    macro avg       0.71      0.71      0.71       999
# weighted avg       0.71      0.71      0.71       999

# %% [markdown]
# ---
# ## Feature Importance by Analyze and visualize feature importances for tree-based models.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Get feature importances from the trained Random Forest model
feature_importances = final_rf_model.feature_importances_

# Create a DataFrame to store feature names and their importance scores
feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
})

# Sort features by importance (highest to lowest)
feature_importance_df = feature_importance_df.sort_values(by="Importance", ascending=False)

# Print feature importance values
print("🔹 **Feature Importance Scores**")
print(feature_importance_df)

# Plot feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance_df["Importance"], y=feature_importance_df["Feature"], palette="viridis")
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("🔹 Feature Importance in Random Forest Model")
plt.show()
# Out:
# 🔹 **Feature Importance Scores**
#            Feature  Importance
# 4          Sulfate    0.140445
# 0               ph    0.137702
# 3      Chloramines    0.116670
# 1         Hardness    0.115102
# 2           Solids    0.109678
# 5     Conductivity    0.097715
# 8        Turbidity    0.096198
# 6   Organic_carbon    0.095221
# 7  Trihalomethanes    0.091268
# c:\Users\Pavan Achari\.conda\envs\water_potablility\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128313 (\N{SMALL BLUE DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **Observation:**
# ## Most Important Features:
#
# - Sulfate and pH are the two most influential factors in predicting water potability.
# - These features have the highest importance scores, indicating a strong impact on model predictions.
# - Possible reason: Sulfate and pH levels affect water safety and quality, making them critical indicators.
#
# ## Moderately Important Features:
#
# - Chloramines, Hardness, and Solids also contribute significantly.
# - These parameters impact water purification processes and overall safety.
#
# ## Less Important but Still Relevant Features:
#
# - Conductivity, Turbidity, Organic Carbon, and Trihalomethanes have lower importance scores.
# - While these factors affect water quality, their impact is relatively smaller compared to Sulfate and pH.
#
# ---

# %% [markdown]
# # Results and Visualization: Visualizing model performance and summarize findings.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# ✅ Predictions on the test set
y_pred = final_rf_model.predict(X_test)
y_pred_prob = final_rf_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC Curve

# ✅ Print Classification Report
print("🔹 **Classification Report**")
print(classification_report(y_test, y_pred))

# ✅ Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# ✅ Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Not Potable", "Potable"], yticklabels=["Not Potable", "Potable"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("🔹 Confusion Matrix")
plt.show()

# ✅ ROC Curve & AUC Score
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color="blue", label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")  # Diagonal line for reference
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("🔹 ROC Curve")
plt.legend()
plt.show()

# ✅ Print AUC Score
print(f"🔹 **AUC Score:** {roc_auc:.3f}")
# Out:
# 🔹 **Classification Report**
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.73      0.72       500
#          1.0       0.72      0.70      0.71       499
#
#     accuracy                           0.71       999
#    macro avg       0.71      0.71      0.71       999
# weighted avg       0.71      0.71      0.71       999
# c:\Users\Pavan Achari\.conda\envs\water_potablility\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128313 (\N{SMALL BLUE DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Pavan Achari\.conda\envs\water_potablility\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128313 (\N{SMALL BLUE DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 🔹 **AUC Score:** 0.794

# %%
import joblib
from sklearn.ensemble import RandomForestClassifier

# Train your model (replace with actual training code)
final_rf_model = RandomForestClassifier(random_state=42)
final_rf_model.fit(X_train, y_train)  # Train the model using X_train and y_train

# Save only the trained model
joblib.dump(final_rf_model, "models/final_rf_model.save")
print(f"Final Random Forest model saved successfully!")
# Out:
# Final Random Forest model saved successfully!

# %% [markdown]
# ## The model is saved and is ready for deployment

# %% [markdown]
# ### Run the streamlit app by the following command (python -m streamlit run app.py)
#
# ---

# %% [markdown]
# ### Model Performance Metrics:
# - Accuracy: 71.3% – The model correctly predicts potability 71.3% of the time.
# - Precision: 71.9% – When the model predicts a class as potable (1), it is correct 71.9% of the time.
# - Recall: 69.7% – Out of all actual potable water instances, the model identifies 69.7% correctly.
# - F1-Score: 70.8% – A balanced measure of precision and recall.
# - AUC Score: 79.4% – Measures the model’s ability to distinguish between potable and non-potable water. A score close to 1 indicates better performance.
#
# ### Interpretation of Values
# - True Negatives (TN = 364) → Correctly predicted non-potable water.
# - False Positives (FP = 136) → Incorrectly classified non-potable water as potable (risk of unsafe water being considered drinkable).
# - False Negatives (FN = 151) → Incorrectly classified potable water as non-potable (safe water discarded).
# - True Positives (TP = 348) → Correctly predicted potable water.
#
# ### Performance Analysis:
#
# - The ROC curve is above the diagonal line, showing the model performs better than random guessing.
# - The closer the curve is to the top-left, the better the classification performance.
# - The model effectively differentiates between the two classes.
# ---
